# %%
import pywikibot
import pandas as pd
from tqdm.notebook import tqdm

# %%
df = pd.read_excel("Tabel van verkiezingen.xlsx")
df
# Out:
#       List         Party Candidate number            Candidate name  N_votes  \
# 0      1.0           VVD                1                 Rutte, M.  1760117
# 1      1.0           VVD                2  Hennis-Plasschaert, J.A.   148431
# 2      1.0           VVD                3              Zijlstra, H.    20307
# 3      1.0           VVD                4               van Ark, T.    13557
# 4      1.0           VVD                5        Dijkhoff, K.H.D.M.   146226
# ...    ...           ...              ...                       ...      ...
# 1420   NaN   De Groenen               NaN           D. (David) Blik       66
# 1421   NaN  JEZUS LEEFT               NaN      F.I.A.  van der Spek     6433
# 1422   NaN  JEZUS LEEFT               NaN           M.J.  Westhoven     1008
# 1423   NaN  JEZUS LEEFT               NaN        J.A.C.  van Ooijen      851
# 1424   1.0           VVD                1                 Rutte, M.  2129000
#
#                                   Election Party_WD_id Person_WD_id  \
# 0                        Tweede Kamer 2017     Q239333       Q57792
# 1                        Tweede Kamer 2017     Q239333      Q457884
# 2                        Tweede Kamer 2017     Q239333     Q1375236
# 3                        Tweede Kamer 2017     Q239333     Q4363961
# 4                        Tweede Kamer 2017     Q239333     Q2784118
# ...                                    ...         ...          ...
# 1420  Europese Parlementsverkiezingen 2019    Q1179915          NaN
# 1421  Europese Parlementsverkiezingen 2019   Q28660340    Q66725360
# 1422  Europese Parlementsverkiezingen 2019   Q28660340          NaN
# 1423  Europese Parlementsverkiezingen 2019   Q28660340          NaN
# 1424                     Tweede Kamer 2012     Q239333       Q57792
#
#      Election_WD_id                                         source_url  \
# 0         Q16061881  https://www.kiesraad.nl/actueel/nieuws/2017/03...
# 1         Q16061881  https://www.kiesraad.nl/actueel/nieuws/2017/03...
# 2         Q16061881  https://www.kiesraad.nl/actueel/nieuws/2017/03...
# 3         Q16061881  https://www.kiesraad.nl/actueel/nieuws/2017/03...
# 4         Q16061881  https://www.kiesraad.nl/actueel/nieuws/2017/03...
# ...             ...                                                ...
# 1420      Q56192579                                                NaN
# 1421      Q56192579                                                NaN
# 1422      Q56192579                                                NaN
# 1423      Q56192579                                                NaN
# 1424       Q1457697                                                NaN
#
#      retrieved_date
# 0        2020-12-28
# 1        2020-12-28
# 2        2020-12-28
# 3        2020-12-28
# 4        2020-12-28
# ...             ...
# 1420            NaT
# 1421            NaT
# 1422            NaT
# 1423            NaT
# 1424            NaT
#
# [1425 rows x 11 columns]

# %%
site = pywikibot.Site("wikidata")
repo = site.data_repository()

candidacy = 'P3602'

for index, row in tqdm(df.iterrows()):
    add_reference = False
    print(row["Person_WD_id"])
    item = pywikibot.ItemPage(repo, row["Person_WD_id"])
    try:
        item.get()
    except:
        continue
    if index > 3: break

    if candidacy in item.claims:
        list_of_claims = [
            claim for claim in item.claims[candidacy]
            if row['Election_WD_id'] in str(claim.getTarget())
        ]
    else:
        list_of_claims = []

    if len(list_of_claims) == 0:
        claim = pywikibot.Claim(repo, candidacy)
        claim.setTarget(pywikibot.ItemPage(repo, row['Election_WD_id']))
        item.addClaim(claim,
                      summary=u'Added candidacy in %s' % row['Election_WD_id'])
        add_reference = True
        # Create new list of claims
        list_of_claims = [
            claim for claim in item.claims[candidacy]
            if row['Election_WD_id'] in str(claim.getTarget())
        ]

    # Add position on list
    if 'P1545' not in item.claims[candidacy][0].qualifiers:
        qualifier = pywikibot.Claim(repo, u'P1545')
        qualifier.setTarget(pywikibot.WbQuantity(row["Candidate number"]))
        item.claims[candidacy][0].addQualifier(
            qualifier, summary=u"Added position on list")
        add_reference = True

    # Add party
    if 'P1268' not in item.claims[candidacy][0].qualifiers:
        qualifier = pywikibot.Claim(repo, u'P1268')
        qualifier.setTarget(pywikibot.ItemPage(repo, row['Party_WD_id']))
        item.claims[candidacy][0].addQualifier(
            qualifier, summary=u"Added represented party")
        add_reference = True

    # Add number of votes
    if 'P1111' not in item.claims[candidacy][0].qualifiers:
        qualifier = pywikibot.Claim(repo, u'P1111')
        qualifier.setTarget(pywikibot.WbQuantity(row["n_votes"]))
        item.claims[candidacy][0].addQualifier(
            qualifier, summary=u"Added number of votes")
        add_reference = True

    if add_reference:
        url = pywikibot.Claim(repo, u'P813')
        retrieved.setTarget(row["source_url"])

        retrieved = pywikibot.Claim(repo, u'P813')
        date = pywikibot.WbTime(year=2020, month=12, day=28)
        retrieved.setTarget(date)

        item.claims[candidacy][0].addSources([url, retrieved],
                                             summary=u'Adding sources.')
